# %%
import pandas as pd

# %% [markdown]
# 데이터프레임 생성(row단위 list)

# %%
df = pd.DataFrame(
    [[1,2,3],[4,5,6],[7,8,9]],
    index = [1,2,3],
    columns = ['a', 'b', 'c']
)
df
# Out:
#    a  b  c
# 1  1  2  3
# 2  4  5  6
# 3  7  8  9

# %% [markdown]
# 데이터 미리보기, 데이터 프레임 크기, 데이터 컬럼명 보기, 높은순보기/낮은순보기

# %%
df = pd.read_csv('scores.csv')
# df.head(3)
# df.tail(3)
# df.sample(3)

# df.shape
# len(df)

# df.columns

# df.nlargest(5,'국어')
# df.nsmallest(5, '국어')
# Out:
#         이름    국어  영어    수학
# 7    peter  50.0  60   NaN
# 5    james  70.0  75  65.0
# 10   james  70.0  75  65.0
# 6   daniel  80.0  90  55.0
# 1   olivia  90.0  80  75.0

# %% [markdown]
# 연습하기

# %%
df = pd.read_csv('scores.csv')
# df.head(1)
# df.tail(1)
# df.sample(3)

# df.shape[1]

# df.columns[0]

# df.nlargest(1,'영어')
df.nsmallest(1, '영어')['이름']
# Out:
# 4    amy
# Name: 이름, dtype: object

# %% [markdown]
# 데이터 추출하기 (열단위 추출 데이터프레임)

# %%
df_kor = df[['이름','국어']]
df_kor.head(3)
